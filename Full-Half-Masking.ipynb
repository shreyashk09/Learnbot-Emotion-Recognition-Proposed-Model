# %%
from imutils import face_utils
import numpy as np
import argparse
import imutils
import dlib
import cv2
rgb = cv2.VideoCapture(0)
detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor("shape_predictor_68_face_landmarks.dat")
clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))

while True:
    ret, image = rgb.read()
    blank = cv2.imread('blank.png')
    org = image
    image = imutils.resize(image, width=300)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    gray = clahe.apply(gray)
    rects = detector(gray, 1)
    for (i, rect) in enumerate(rects):
        shape = predictor(gray, rect)
        shape = face_utils.shape_to_np(shape)
        (x, y, w, h) = face_utils.rect_to_bb(rect)
        #for (x, y) in shape:
        #   cv2.circle(image, (x, y), 1, (0, 0, 255), -1)
        x1=[]
        y1=[]
        for (x, y) in shape:
            x1.append(x)
            y1.append(y)
            cv2.circle(image, (x, y), 1, (0, 0, 255), -1)
        image = Fullmask(image,x1,y1)
        blank = Fullmask(blank,x1,y1)
    if cv2.waitKey(1) == 27:
        break
    cv2.imshow('Filter1', org)
    cv2.imshow('Filter2', image)
    cv2.imshow('Filter3', blank)
cv2.destroyAllWindows()

# %%
from imutils import face_utils
import numpy as np
import argparse
import imutils
import dlib
import cv2

detector = dlib.get_frontal_face_detector()
clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
predictor = dlib.shape_predictor("shape_predictor_68_face_landmarks.dat")
image = cv2.imread("angry.png",1)
blank = cv2.imread("blank.png",1)
image = imutils.resize(image, width=600,height=600)
blank = imutils.resize(blank, width=1000,height=1000)

gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
claheim = clahe.apply(gray)
cv2.imshow('gray1 image', gray)
cv2.imshow('clache1 image',claheim)
rects = detector(gray, 1)
for (i, rect) in enumerate(rects):
    shape = predictor(gray, rect)
    shape = face_utils.shape_to_np(shape)
    (x, y, w, h) = face_utils.rect_to_bb(rect)
    x1=[]
    y1=[]
#     shape = shape.tolist()
    for (x, y) in shape:
        x1.append(x)
        y1.append(y)
        cv2.circle(blank, (x, y), 1, (0, 0, 255), -1)
        cv2.circle(image, (x, y), 1, (0, 0, 255), -1)
    image = Fullmask(image,x1,y1)
    blank = Fullmask(blank,x1,y1)
cv2.imshow('Left1', image)
cv2.imshow('Filter1', blank)
if cv2.waitKey(1) == 27:
    cv2.destroyAllWindows()

# %%
def Halfmask(image,x,y):
    px=1
    cv2.line(image,(x[17],y[17]),(x[36],y[36]),(255,0,0),px)
    cv2.line(image,(x[18],y[18]),(x[36],y[36]),(255,0,0),px)
    cv2.line(image,(x[19],y[19]),(x[36],y[36]),(255,0,0),px)
    cv2.line(image,(x[20],y[20]),(x[36],y[36]),(255,0,0),px)
    cv2.line(image,(x[21],y[21]),(x[36],y[36]),(255,0,0),px)
    cv2.line(image,(x[37],y[37]),(x[36],y[36]),(255,0,0),px)
    cv2.line(image,(x[48],y[48]),(x[36],y[36]),(255,0,0),px)
    cv2.line(image,(x[37],y[37]),(x[41],y[41]),(255,0,0),px)
    cv2.line(image,(x[37],y[37]),(x[40],y[40]),(255,0,0),px)
    cv2.line(image,(x[40],y[40]),(x[38],y[38]),(255,0,0),px)
    cv2.line(image,(x[18],y[18]),(x[39],y[39]),(255,0,0),px)
    cv2.line(image,(x[19],y[19]),(x[39],y[39]),(255,0,0),px)
    cv2.line(image,(x[20],y[20]),(x[39],y[39]),(255,0,0),px)
    cv2.line(image,(x[21],y[21]),(x[39],y[39]),(255,0,0),px)
    cv2.line(image,(x[22],y[22]),(x[39],y[39]),(255,0,0),px)
    cv2.line(image,(x[27],y[27]),(x[39],y[39]),(255,0,0),px)
    cv2.line(image,(x[27],y[27]),(x[21],y[21]),(255,0,0),px)
    cv2.line(image,(x[27],y[27]),(x[20],y[20]),(255,0,0),px)
    cv2.line(image,(x[27],y[27]),(x[19],y[19]),(255,0,0),px)
    cv2.line(image,(x[40],y[40]),(x[32],y[32]),(255,0,0),px)
    cv2.line(image,(x[40],y[40]),(x[48],y[48]),(255,0,0),px)
    cv2.line(image,(x[40],y[40]),(x[39],y[39]),(255,0,0),px)
    cv2.line(image,(x[17],y[17]),(x[48],y[48]),(255,0,0),px)
    cv2.line(image,(x[59],y[59]),(x[48],y[48]),(255,0,0),px)
    cv2.line(image,(x[49],y[49]),(x[48],y[48]),(255,0,0),px)
    cv2.line(image,(x[31],y[31]),(x[48],y[48]),(255,0,0),px)
    cv2.line(image,(x[61],y[61]),(x[49],y[49]),(255,0,0),px)
    cv2.line(image,(x[61],y[61]),(x[51],y[51]),(255,0,0),px)
    cv2.line(image,(x[33],y[33]),(x[51],y[51]),(255,0,0),px)
    cv2.line(image,(x[31],y[31]),(x[50],y[50]),(255,0,0),px)
    cv2.line(image,(x[33],y[33]),(x[50],y[50]),(255,0,0),px)
    cv2.line(image,(x[62],y[62]),(x[66],y[66]),(255,0,0),px)
    cv2.line(image,(x[62],y[62]),(x[60],y[60]),(255,0,0),px)
    cv2.line(image,(x[50],y[50]),(x[66],y[66]),(255,0,0),px)
    cv2.line(image,(x[60],y[60]),(x[66],y[66]),(255,0,0),px)
    cv2.line(image,(x[58],y[58]),(x[62],y[62]),(255,0,0),px)
    cv2.line(image,(x[59],y[59]),(x[67],y[67]),(255,0,0),px)
    cv2.line(image,(x[57],y[57]),(x[67],y[67]),(255,0,0),px)
    return image
    
#     cv2.line(image,(x[],y[]),(x[],y[]),(255,0,0),px)
#     cv2.line(image,(x[],y[]),(x[],y[]),(255,0,0),px)
#     cv2.line(image,(x[],y[]),(x[],y[]),(255,0,0),px)
#     cv2.line(image,(x[],y[]),(x[],y[]),(255,0,0),px)
#     cv2.line(image,(x[],y[]),(x[],y[]),(255,0,0),px)
#     cv2.line(image,(x[],y[]),(x[],y[]),(255,0,0),px)

# %%
def Fullmask(image,x,y):
    px=1
    cv2.line(image,(x[17],y[17]),(x[36],y[36]),(255,0,0),px)
    cv2.line(image,(x[18],y[18]),(x[36],y[36]),(255,0,0),px)
    cv2.line(image,(x[19],y[19]),(x[36],y[36]),(255,0,0),px)
    cv2.line(image,(x[20],y[20]),(x[36],y[36]),(255,0,0),px)
    cv2.line(image,(x[21],y[21]),(x[36],y[36]),(255,0,0),px)
    cv2.line(image,(x[37],y[37]),(x[36],y[36]),(255,0,0),px)
    cv2.line(image,(x[48],y[48]),(x[36],y[36]),(255,0,0),px)
    cv2.line(image,(x[37],y[37]),(x[41],y[41]),(255,0,0),px)
    cv2.line(image,(x[37],y[37]),(x[40],y[40]),(255,0,0),px)
    cv2.line(image,(x[40],y[40]),(x[38],y[38]),(255,0,0),px)
    cv2.line(image,(x[18],y[18]),(x[39],y[39]),(255,0,0),px)
    cv2.line(image,(x[19],y[19]),(x[39],y[39]),(255,0,0),px)
    cv2.line(image,(x[20],y[20]),(x[39],y[39]),(255,0,0),px)
    cv2.line(image,(x[21],y[21]),(x[39],y[39]),(255,0,0),px)
    cv2.line(image,(x[22],y[22]),(x[39],y[39]),(255,0,0),px)
    cv2.line(image,(x[27],y[27]),(x[39],y[39]),(255,0,0),px)
    cv2.line(image,(x[27],y[27]),(x[21],y[21]),(255,0,0),px)
    cv2.line(image,(x[27],y[27]),(x[20],y[20]),(255,0,0),px)
    cv2.line(image,(x[27],y[27]),(x[19],y[19]),(255,0,0),px)
    cv2.line(image,(x[40],y[40]),(x[32],y[32]),(255,0,0),px)
    cv2.line(image,(x[40],y[40]),(x[48],y[48]),(255,0,0),px)
    cv2.line(image,(x[40],y[40]),(x[39],y[39]),(255,0,0),px)
    cv2.line(image,(x[17],y[17]),(x[48],y[48]),(255,0,0),px)
    cv2.line(image,(x[59],y[59]),(x[48],y[48]),(255,0,0),px)
    cv2.line(image,(x[49],y[49]),(x[48],y[48]),(255,0,0),px)
    cv2.line(image,(x[31],y[31]),(x[48],y[48]),(255,0,0),px)
    cv2.line(image,(x[61],y[61]),(x[49],y[49]),(255,0,0),px)
    cv2.line(image,(x[61],y[61]),(x[51],y[51]),(255,0,0),px)
    cv2.line(image,(x[33],y[33]),(x[51],y[51]),(255,0,0),px)
    cv2.line(image,(x[31],y[31]),(x[50],y[50]),(255,0,0),px)
    cv2.line(image,(x[33],y[33]),(x[50],y[50]),(255,0,0),px)
    cv2.line(image,(x[62],y[62]),(x[66],y[66]),(255,0,0),px)
    cv2.line(image,(x[62],y[62]),(x[60],y[60]),(255,0,0),px)
    cv2.line(image,(x[50],y[50]),(x[66],y[66]),(255,0,0),px)
    cv2.line(image,(x[60],y[60]),(x[66],y[66]),(255,0,0),px)
    cv2.line(image,(x[58],y[58]),(x[62],y[62]),(255,0,0),px)
    cv2.line(image,(x[59],y[59]),(x[67],y[67]),(255,0,0),px)
    cv2.line(image,(x[57],y[57]),(x[67],y[67]),(255,0,0),px)
#     return image
    
    cv2.line(image,(x[22],y[22]),(x[27],y[27]),(255,0,0),px)
    cv2.line(image,(x[23],y[23]),(x[27],y[27]),(255,0,0),px)
    cv2.line(image,(x[24],y[24]),(x[27],y[27]),(255,0,0),px)
    cv2.line(image,(x[42],y[42]),(x[27],y[27]),(255,0,0),px)
    cv2.line(image,(x[22],y[22]),(x[42],y[42]),(255,0,0),px)
    cv2.line(image,(x[23],y[23]),(x[42],y[42]),(255,0,0),px)
    cv2.line(image,(x[24],y[24]),(x[42],y[42]),(255,0,0),px)
    cv2.line(image,(x[25],y[25]),(x[42],y[42]),(255,0,0),px)
    cv2.line(image,(x[47],y[47]),(x[42],y[42]),(255,0,0),px)
    cv2.line(image,(x[22],y[22]),(x[45],y[45]),(255,0,0),px)
    cv2.line(image,(x[23],y[23]),(x[45],y[45]),(255,0,0),px)
    cv2.line(image,(x[24],y[24]),(x[45],y[45]),(255,0,0),px)
    cv2.line(image,(x[25],y[25]),(x[45],y[45]),(255,0,0),px)
    cv2.line(image,(x[26],y[26]),(x[45],y[45]),(255,0,0),px)
    cv2.line(image,(x[54],y[54]),(x[45],y[45]),(255,0,0),px)
    cv2.line(image,(x[34],y[34]),(x[47],y[47]),(255,0,0),px)
    cv2.line(image,(x[54],y[54]),(x[47],y[47]),(255,0,0),px)
    cv2.line(image,(x[44],y[44]),(x[47],y[47]),(255,0,0),px)
    cv2.line(image,(x[44],y[44]),(x[46],y[46]),(255,0,0),px)
    cv2.line(image,(x[43],y[43]),(x[47],y[47]),(255,0,0),px)
    cv2.line(image,(x[44],y[44]),(x[45],y[45]),(255,0,0),px)
    cv2.line(image,(x[26],y[26]),(x[54],y[54]),(255,0,0),px)
    cv2.line(image,(x[35],y[35]),(x[54],y[54]),(255,0,0),px)
    cv2.line(image,(x[53],y[53]),(x[54],y[54]),(255,0,0),px)
    cv2.line(image,(x[55],y[55]),(x[54],y[54]),(255,0,0),px)
    cv2.line(image,(x[52],y[52]),(x[66],y[66]),(255,0,0),px)
    cv2.line(image,(x[52],y[52]),(x[35],y[35]),(255,0,0),px)
    cv2.line(image,(x[52],y[52]),(x[33],y[33]),(255,0,0),px)
    cv2.line(image,(x[64],y[64]),(x[66],y[66]),(255,0,0),px)
    cv2.line(image,(x[64],y[64]),(x[62],y[62]),(255,0,0),px)
    cv2.line(image,(x[56],y[56]),(x[62],y[62]),(255,0,0),px)
    cv2.line(image,(x[57],y[57]),(x[65],y[65]),(255,0,0),px)
    cv2.line(image,(x[55],y[55]),(x[65],y[65]),(255,0,0),px)
    cv2.line(image,(x[63],y[63]),(x[51],y[51]),(255,0,0),px)
    cv2.line(image,(x[63],y[63]),(x[53],y[53]),(255,0,0),px)
#     cv2.line(image,(x[],y[]),(x[],y[]),(255,0,0),px)
#     cv2.line(image,(x[],y[]),(x[],y[]),(255,0,0),px)
#     cv2.line(image,(x[],y[]),(x[],y[]),(255,0,0),px)
#     cv2.line(image,(x[],y[]),(x[],y[]),(255,0,0),px)
#     cv2.line(image,(x[],y[]),(x[],y[]),(255,0,0),px)
#     cv2.line(image,(x[],y[]),(x[],y[]),(255,0,0),px)
#     cv2.line(image,(x[],y[]),(x[],y[]),(255,0,0),px)
#     cv2.line(image,(x[],y[]),(x[],y[]),(255,0,0),px)
   
    return image
